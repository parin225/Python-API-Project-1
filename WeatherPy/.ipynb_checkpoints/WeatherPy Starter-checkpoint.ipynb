# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---

# %%
#dependencies and setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import openweathermapy as ow
import json

#import API key
from api_keys import api_key

#incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

#output file (CSV)
output_data_file = "output_data/cities.csv"

#range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
#list for holding lat_lngs and cities
lat_lngs = []
cities = []

#create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

#identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    #if the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

#print the city count to confirm sufficient count
len(cities)
# Out:
# 590

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it's being processed (with the city number and city name).

# %%
#create an empty list
city_weather = []

#create a counter and set it to 0 to number each city 
counter = 0

#base url
url = "http://api.openweathermap.org/data/2.5/weather?"

#create print statements before retrieving city name
print("Beginning Data Retrieval")
print("---------------------------------")

#create a for statement
for city in cities:
    
    #set parameters to create a specific url
    params = {"appid": api_key,
              "units": "imperial",
              "q": city
             }
    
    #create exact url with parameters and get it in JSON format
    city_response = requests.get(url, params=params)
    city_json = city_response.json()
    
    #use this statement to view in pretty print JSON format
    #commented out after extracting information in the try & except section:
    
    #print(json.dumps(city_json, indent=4, sort_keys=True))  
    
    #create a timer so the api key does not get locked out. Stop the code for 1 second in between
    time.sleep(1)

    #set counter to +1 to increase the number by 1 for each city
    counter += 1
    
    #create a print statement of each city as it is being processed
    print(f"Processing record {counter}|{city}")

    
    #create a try and except to skip through errors
    try:
        city_name = city_json["name"]
        city_clouds = city_json["clouds"]["all"]
        city_country = city_json["sys"]["country"]
        city_date = city_json["dt"]
        city_humidity = city_json["main"]["humidity"]
        city_latitude = city_json["coord"]["lat"]
        city_longitude = city_json["coord"]["lon"]
        city_max_temp = city_json["main"]["temp_max"]
        city_wind_speed = city_json["wind"]["speed"]
        
        #create a list of dictionaries and append weather data for each city into empty city_weather list 
        city_weather.append({"City": city_name,
                            "Cloudiness": city_clouds, 
                            "Country": city_country,
                            "Date": city_date,
                            "Humidity": city_humidity,
                            "Lat": city_latitude,
                            "Lng": city_longitude,
                            "Max Temp": city_max_temp,
                            "Wind Speed": city_wind_speed
                            })  
    
    except (KeyError, IndexError):
        print("City not found. Skipping...")

#create print statememnt after retrieving all city names 
print("---------------------------------")
print("Data Retrieval Complete")
print("---------------------------------")
# Out:
# Beginning Data Retrieval
# ---------------------------------
# Processing record 1|pedasi
# Processing record 2|mataura
# Processing record 3|esperance
# Processing record 4|butaritari
# Processing record 5|vilyuysk
# Processing record 6|hualmay
# Processing record 7|kapaa
# Processing record 8|wattegama
# Processing record 9|bluff
# Processing record 10|mys shmidta
# City not found. Skipping...
# Processing record 11|victoria
# Processing record 12|buraydah
# Processing record 13|warrington
# Processing record 14|dikson
# Processing record 15|ushuaia
# Processing record 16|east london
# Processing record 17|ilulissat
# Processing record 18|fortuna
# Processing record 19|oparino
# Processing record 20|hengshui
# Processing record 21|akdepe
# Processing record 22|saskylakh
# Processing record 23|reyes
# Processing record 24|male
# Processing record 25|port elizabeth
# Processing record 26|riom
# Processing record 27|san patricio
# Processing record 28|nuuk
# Processing record 29|illoqqortoormiut
# City not found. Skipping...
# Processing record 30|yellowknife
# Processing record 31|qaanaaq
# Processing record 32|port hardy
# Processing record 33|nikolskoye
# Processing record 34|rikitea
# Processing record 35|yomitan
# City not found. Skipping...
# Processing record 36|fruitvale
# Processing record 37|pevek
# Processing record 38|pitimbu
# Processing record 39|samusu
# City not found. Skipping...
# Processing record 40|ribeira grande
# Processing record 41|constitucion
# Processing record 42|thompson
# Processing record 43|scarborough
# Processing record 44|muncar
# Processing record 45|bunia
# Processing record 46|tuktoyaktuk
# Processing record 47|umzimvubu
# City not found. Skipping...
# Processing record 48|bengkulu
# City not found. Skipping...
# Processing record 49|muros
# Processing record 50|cape town
# Processing record 51|horodniceni
# Processing record 52|krasnoselkup
# City not found. Skipping...
# Processing record 53|hilo
# Processing record 54|nhulunbuy
# Processing record 55|camopi
# Processing record 56|katsuura
# Processing record 57|busselton
# Processing record 58|horizonte
# Processing record 59|west bay
# Processing record 60|kuytun
# Processing record 61|falmouth
# Processing record 62|luderitz
# Processing record 63|hofn
# Processing record 64|margate
# Processing record 65|kahului
# Processing record 66|caravelas
# Processing record 67|xichang
# Processing record 68|atuona
# Processing record 69|jamestown
# Processing record 70|kloulklubed
# Processing record 71|yuzhno-sukhokumsk
# Processing record 72|koshurnikovo
# Processing record 73|zaozerne
# Processing record 74|los llanos de aridane
# Processing record 75|shimoda
# Processing record 76|torbay
# Processing record 77|avarua
# Processing record 78|ornskoldsvik
# Processing record 79|barentsburg
# City not found. Skipping...
# Processing record 80|teya
# Processing record 81|grafton
# Processing record 82|tuatapere
# Processing record 83|bartica
# Processing record 84|barranca
# Processing record 85|aklavik
# Processing record 86|marion
# Processing record 87|vaini
# Processing record 88|mar del plata
# Processing record 89|alofi
# Processing record 90|provideniya
# Processing record 91|makakilo city
# Processing record 92|punta arenas
# Processing record 93|saint-philippe
# Processing record 94|whitehorse
# Processing record 95|vaitupu
# City not found. Skipping...
# Processing record 96|gazanjyk
# Processing record 97|hays
# Processing record 98|upernavik
# Processing record 99|kushmurun
# City not found. Skipping...
# Processing record 100|severo-yeniseyskiy
# Processing record 101|semey
# Processing record 102|souillac
# Processing record 103|puerto ayora
# Processing record 104|castro alves
# Processing record 105|petropavlovsk-kamchatskiy
# Processing record 106|tumannyy
# City not found. Skipping...
# Processing record 107|leningradskiy
# Processing record 108|geraldton
# Processing record 109|georgetown
# Processing record 110|abu zabad
# Processing record 111|tsihombe
# City not found. Skipping...
# Processing record 112|new norfolk
# Processing record 113|isabela
# Processing record 114|nouadhibou
# Processing record 115|bambous virieux
# Processing record 116|sept-iles
# Processing record 117|karasjok
# Processing record 118|christchurch
# Processing record 119|niquero
# Processing record 120|palomares
# Processing record 121|cidreira
# Processing record 122|belushya guba
# City not found. Skipping...
# Processing record 123|paamiut
# Processing record 124|pangoa
# Processing record 125|taolanaro
# City not found. Skipping...
# Processing record 126|cabo san lucas
# Processing record 127|nipawin
# Processing record 128|grand river south east
# City not found. Skipping...
# Processing record 129|veisiejai
# Processing record 130|ormoz
# Processing record 131|albany
# Processing record 132|bredasdorp
# Processing record 133|ponta do sol
# Processing record 134|severo-kurilsk
# Processing record 135|arraial do cabo
# Processing record 136|iturama
# Processing record 137|coquimbo
# Processing record 138|mount gambier
# Processing record 139|doctor pedro p. pena
# City not found. Skipping...
# Processing record 140|rocha
# Processing record 141|castro
# Processing record 142|faanui
# Processing record 143|vostok
# Processing record 144|chake chake
# Processing record 145|dalby
# Processing record 146|bima
# Processing record 147|stokmarknes
# Processing record 148|tarudant
# City not found. Skipping...
# Processing record 149|saint george
# Processing record 150|jerez
# Processing record 151|puerto baquerizo moreno
# Processing record 152|gimli
# Processing record 153|nowe miasto lubawskie
# Processing record 154|port alfred
# Processing record 155|kristianstad
# Processing record 156|benin
# City not found. Skipping...
# Processing record 157|bowen
# Processing record 158|lata
# Processing record 159|lieksa
# Processing record 160|tautira
# Processing record 161|presidencia roque saenz pena
# Processing record 162|ancud
# Processing record 163|oktyabrskiy
# Processing record 164|balabac
# Processing record 165|chandla
# Processing record 166|sidi qasim
# City not found. Skipping...
# Processing record 167|nirmal
# Processing record 168|carnarvon
# Processing record 169|bargal
# City not found. Skipping...
# Processing record 170|clyde river
# Processing record 171|yarega
# Processing record 172|vidim
# Processing record 173|sitka
# Processing record 174|nemuro
# Processing record 175|dukat
# Processing record 176|sao filipe
# Processing record 177|stornoway
# City not found. Skipping...
# Processing record 178|tongsa
# City not found. Skipping...
# Processing record 179|padang
# Processing record 180|harper
# Processing record 181|wohlen
# Processing record 182|saint-augustin
# Processing record 183|honningsvag
# Processing record 184|hermanus
# Processing record 185|te anau
# Processing record 186|bethel
# Processing record 187|entebbe
# Processing record 188|ahuimanu
# Processing record 189|attawapiskat
# City not found. Skipping...
# Processing record 190|tasiilaq
# Processing record 191|hobart
# Processing record 192|meyungs
# City not found. Skipping...
# Processing record 193|khatanga
# Processing record 194|roma
# Processing record 195|xuddur
# Processing record 196|vila velha
# Processing record 197|ust-nera
# Processing record 198|ballina
# Processing record 199|aleksandrovskoye
# Processing record 200|lagoa
# Processing record 201|saint-joseph
# Processing record 202|chumikan
# Processing record 203|jalingo
# Processing record 204|gorno-chuyskiy
# City not found. Skipping...
# Processing record 205|hopkinsville
# Processing record 206|datong
# Processing record 207|namibe
# Processing record 208|hudson bay
# Processing record 209|toliary
# City not found. Skipping...
# Processing record 210|zhigansk
# Processing record 211|dekernes
# Processing record 212|iskateley
# Processing record 213|urusha
# Processing record 214|muscat
# Processing record 215|paradwip
# City not found. Skipping...
# Processing record 216|deputatskiy
# Processing record 217|crotone
# Processing record 218|cockburn town
# Processing record 219|puerto del rosario
# Processing record 220|talnakh
# Processing record 221|gustavo diaz ordaz
# Processing record 222|yulara
# Processing record 223|sawakin
# Processing record 224|bilibino
# Processing record 225|aventura
# Processing record 226|sangar
# Processing record 227|lasa
# Processing record 228|ahipara
# Processing record 229|chokurdakh
# Processing record 230|altay
# Processing record 231|raudeberg
# Processing record 232|yerbogachen
# Processing record 233|labuhan
# Processing record 234|hithadhoo
# Processing record 235|sheregesh
# Processing record 236|pringsewu
# Processing record 237|la orilla
# Processing record 238|celestun
# Processing record 239|narsaq
# Processing record 240|tiksi
# Processing record 241|guerrero negro
# Processing record 242|kaeo
# Processing record 243|college
# Processing record 244|kodiak
# Processing record 245|cherskiy
# Processing record 246|vardo
# Processing record 247|quatre cocos
# Processing record 248|mamlyutka
# Processing record 249|colac
# Processing record 250|beni
# Processing record 251|norman wells
# Processing record 252|fairbanks
# Processing record 253|hasaki
# Processing record 254|champasak
# Processing record 255|springbok
# Processing record 256|amderma
# City not found. Skipping...
# Processing record 257|suntar
# Processing record 258|praya
# Processing record 259|palmer
# Processing record 260|sarana
# Processing record 261|rapid valley
# Processing record 262|linares
# Processing record 263|gizo
# Processing record 264|pisco
# Processing record 265|mahebourg
# Processing record 266|lerik
# Processing record 267|isangel
# Processing record 268|lebu
# Processing record 269|sorong
# Processing record 270|komsomolskiy
# Processing record 271|barrow
# Processing record 272|muromtsevo
# Processing record 273|saleaula
# City not found. Skipping...
# Processing record 274|bang sao thong
# Processing record 275|odlabari
# Processing record 276|carauari
# Processing record 277|samarai
# Processing record 278|nizhneyansk
# City not found. Skipping...
# Processing record 279|cardston
# Processing record 280|carpi
# Processing record 281|lingao
# Processing record 282|pecos
# Processing record 283|palmares do sul
# Processing record 284|ondorhaan
# City not found. Skipping...
# Processing record 285|machado
# Processing record 286|maldonado
# Processing record 287|auki
# Processing record 288|prince rupert
# Processing record 289|malwan
# City not found. Skipping...
# Processing record 290|puerto carreno
# Processing record 291|abnub
# Processing record 292|sargatskoye
# Processing record 293|gunjur
# Processing record 294|kyra
# City not found. Skipping...
# Processing record 295|ellensburg
# Processing record 296|marathon
# Processing record 297|havelock
# Processing record 298|vao
# Processing record 299|saldanha
# Processing record 300|rovaniemi
# Processing record 301|kaitangata
# Processing record 302|qaqortoq
# Processing record 303|kandrian
# Processing record 304|brae
# Processing record 305|nanortalik
# Processing record 306|hambantota
# Processing record 307|tabuk
# Processing record 308|port macquarie
# Processing record 309|naze
# Processing record 310|rio grande
# Processing record 311|rio gallegos
# Processing record 312|pareora
# Processing record 313|tartus
# City not found. Skipping...
# Processing record 314|mchinji
# Processing record 315|caloundra
# Processing record 316|jinchang
# Processing record 317|haines junction
# Processing record 318|sant feliu de guixols
# Processing record 319|baruun-urt
# Processing record 320|bullhead city
# Processing record 321|muzhi
# Processing record 322|roald
# Processing record 323|colares
# Processing record 324|kavieng
# Processing record 325|palabuhanratu
# City not found. Skipping...
# Processing record 326|polyarnyy
# Processing record 327|abha
# Processing record 328|russell
# Processing record 329|barra patuca
# Processing record 330|mozhaysk
# Processing record 331|shaowu
# Processing record 332|jidong
# Processing record 333|namatanai
# Processing record 334|pangnirtung
# Processing record 335|bandarbeyla
# Processing record 336|xam nua
# Processing record 337|sentyabrskiy
# City not found. Skipping...
# Processing record 338|port-gentil
# Processing record 339|samana
# Processing record 340|hope
# Processing record 341|nguiu
# City not found. Skipping...
# Processing record 342|faya
# Processing record 343|sakakah
# City not found. Skipping...
# Processing record 344|airai
# Processing record 345|zyryanovsk
# Processing record 346|port hedland
# Processing record 347|karamken
# City not found. Skipping...
# Processing record 348|jacareacanga
# Processing record 349|marsabit
# Processing record 350|alyangula
# Processing record 351|santa cruz
# Processing record 352|moerai
# Processing record 353|belaya gora
# Processing record 354|yala
# Processing record 355|comodoro rivadavia
# Processing record 356|swan river
# Processing record 357|huesca
# Processing record 358|madimba
# Processing record 359|northam
# Processing record 360|berovo
# Processing record 361|bubaque
# Processing record 362|alice springs
# Processing record 363|minuri
# Processing record 364|qasigiannguit
# Processing record 365|lazaro cardenas
# Processing record 366|yarada
# Processing record 367|aykhal
# Processing record 368|bollnas
# Processing record 369|umm kaddadah
# Processing record 370|pedernales
# Processing record 371|port blair
# Processing record 372|yaransk
# Processing record 373|kavaratti
# Processing record 374|paidha
# Processing record 375|gawler
# Processing record 376|senj
# Processing record 377|dauriya
# Processing record 378|phnum penh
# City not found. Skipping...
# Processing record 379|galgani
# City not found. Skipping...
# Processing record 380|porto novo
# Processing record 381|mitsamiouli
# Processing record 382|faro
# Processing record 383|dong xoai
# Processing record 384|paramonga
# Processing record 385|ust-omchug
# Processing record 386|shizunai
# Processing record 387|benjamin constant
# Processing record 388|phan rang
# City not found. Skipping...
# Processing record 389|garissa
# Processing record 390|yumen
# Processing record 391|moen
# Processing record 392|de-kastri
# Processing record 393|san pedro
# Processing record 394|seymchan
# Processing record 395|kasongo-lunda
# Processing record 396|sao paulo de olivenca
# Processing record 397|whitecourt
# Processing record 398|sinnamary
# Processing record 399|brusyliv
# Processing record 400|arman
# Processing record 401|havre-saint-pierre
# Processing record 402|berbera
# City not found. Skipping...
# Processing record 403|lilongwe
# Processing record 404|coolum beach
# Processing record 405|takoradi
# Processing record 406|sambava
# Processing record 407|omboue
# Processing record 408|tendukheda
# Processing record 409|banjar
# Processing record 410|kwale
# Processing record 411|balikpapan
# Processing record 412|kalianget
# Processing record 413|kizhinga
# Processing record 414|beidao
# Processing record 415|chuy
# Processing record 416|marica
# Processing record 417|tabou
# Processing record 418|sibolga
# Processing record 419|iqaluit
# Processing record 420|kemijarvi
# City not found. Skipping...
# Processing record 421|cobh
# Processing record 422|genhe
# Processing record 423|guadalupe y calvo
# Processing record 424|tchaourou
# Processing record 425|port augusta
# Processing record 426|charyshskoye
# Processing record 427|tocopilla
# Processing record 428|kruisfontein
# Processing record 429|poum
# Processing record 430|izhma
# Processing record 431|kargasok
# Processing record 432|laguna
# Processing record 433|irbeyskoye
# Processing record 434|rabo de peixe
# Processing record 435|mendi
# Processing record 436|houston
# Processing record 437|bur gabo
# City not found. Skipping...
# Processing record 438|seydi
# Processing record 439|viligili
# City not found. Skipping...
# Processing record 440|barra do garcas
# Processing record 441|maumere
# Processing record 442|myrtle beach
# Processing record 443|erenhot
# Processing record 444|lokoja
# Processing record 445|caceres
# Processing record 446|mirnyy
# Processing record 447|san quintin
# Processing record 448|longyearbyen
# Processing record 449|gallup
# Processing record 450|codrington
# Processing record 451|armidale
# Processing record 452|solnechnyy
# Processing record 453|netivot
# Processing record 454|marcona
# City not found. Skipping...
# Processing record 455|san jose
# Processing record 456|mnogovershinnyy
# Processing record 457|antofagasta
# Processing record 458|adamas
# Processing record 459|mayo
# Processing record 460|oranjestad
# Processing record 461|samalaeulu
# City not found. Skipping...
# Processing record 462|doha
# Processing record 463|zakamensk
# Processing record 464|roebourne
# Processing record 465|kabinda
# Processing record 466|nelson bay
# Processing record 467|palau
# Processing record 468|babat
# Processing record 469|nantucket
# Processing record 470|karratha
# Processing record 471|guaratinga
# City not found. Skipping...
# Processing record 472|itarema
# Processing record 473|valley city
# Processing record 474|srednekolymsk
# Processing record 475|sorvag
# City not found. Skipping...
# Processing record 476|hamilton
# Processing record 477|gouyave
# Processing record 478|grindavik
# Processing record 479|cap malheureux
# Processing record 480|pangody
# Processing record 481|mersing
# Processing record 482|ejido
# Processing record 483|soe
# Processing record 484|boulder city
# Processing record 485|tallahassee
# Processing record 486|mareeba
# Processing record 487|ostrovnoy
# Processing record 488|camalu
# Processing record 489|san fernando
# Processing record 490|anloga
# Processing record 491|lima
# Processing record 492|lujan
# Processing record 493|acapulco
# Processing record 494|sao joao da barra
# Processing record 495|barawe
# City not found. Skipping...
# Processing record 496|salalah
# Processing record 497|ofunato
# Processing record 498|touros
# Processing record 499|dunkirk
# Processing record 500|nyurba
# Processing record 501|keetmanshoop
# Processing record 502|preobrazheniye
# Processing record 503|saint-francois
# Processing record 504|kanigoro
# Processing record 505|xining
# Processing record 506|nome
# Processing record 507|boa vista
# Processing record 508|taksimo
# Processing record 509|avera
# Processing record 510|shahreza
# Processing record 511|arawa
# Processing record 512|nerchinskiy zavod
# Processing record 513|adrar
# Processing record 514|dzaoudzi
# Processing record 515|magura
# Processing record 516|juegang
# Processing record 517|puerto madryn
# Processing record 518|hay river
# Processing record 519|caconda
# Processing record 520|palu
# Processing record 521|minuwangoda
# Processing record 522|matay
# Processing record 523|sechura
# Processing record 524|batemans bay
# Processing record 525|mantua
# Processing record 526|gaffney
# Processing record 527|makaha
# Processing record 528|del rio
# Processing record 529|kantang
# Processing record 530|barcarena
# Processing record 531|truro
# Processing record 532|waipawa
# Processing record 533|khilok
# Processing record 534|lubben
# Processing record 535|simoes
# Processing record 536|kataysk
# Processing record 537|warqla
# City not found. Skipping...
# Processing record 538|yunjinghong
# City not found. Skipping...
# Processing record 539|maceio
# Processing record 540|rawannawi
# City not found. Skipping...
# Processing record 541|borogontsy
# Processing record 542|hobyo
# Processing record 543|clyde
# Processing record 544|magistralnyy
# Processing record 545|teseney
# Processing record 546|fort nelson
# Processing record 547|nara
# Processing record 548|tabas
# Processing record 549|puerto el triunfo
# Processing record 550|southbridge
# Processing record 551|lisakovsk
# Processing record 552|anadyr
# Processing record 553|muzaffarabad
# Processing record 554|pagsangahan
# Processing record 555|methoni
# Processing record 556|olafsvik
# City not found. Skipping...
# Processing record 557|bukachacha
# Processing record 558|elko
# Processing record 559|saint anthony
# Processing record 560|grand gaube
# Processing record 561|pemangkat
# City not found. Skipping...
# Processing record 562|tarragona
# Processing record 563|corinth
# Processing record 564|namyslow
# Processing record 565|baicheng
# Processing record 566|qeshm
# Processing record 567|dom pedrito
# Processing record 568|okha
# Processing record 569|ucluelet
# Processing record 570|dvinskoy
# Processing record 571|klaksvik
# Processing record 572|ruatoria
# City not found. Skipping...
# Processing record 573|linxi
# Processing record 574|venosa
# Processing record 575|pimentel
# Processing record 576|batagay-alyta
# Processing record 577|verkhnyaya inta
# Processing record 578|nizwa
# Processing record 579|luwuk
# Processing record 580|allapalli
# Processing record 581|orgun
# City not found. Skipping...
# Processing record 582|nan
# Processing record 583|aranos
# Processing record 584|porto seguro
# Processing record 585|willowmore
# Processing record 586|tura
# Processing record 587|natal
# Processing record 588|nueva helvecia
# Processing record 589|sydney
# Processing record 590|hazorasp
# ---------------------------------
# Data Retrieval Complete
# ---------------------------------

# %%
#create dataframe and count the number of cities in dataset
city_weather_df = pd.DataFrame(city_weather)

city_weather_df.count()
# Out:
# City          532
# Cloudiness    532
# Country       532
# Date          532
# Humidity      532
# Lat           532
# Lng           532
# Max Temp      532
# Wind Speed    532
# dtype: int64

# %%
#show dataframe from the raw information from the API 

city_weather_df.head()
# Out:
#          City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0      Pedasi           0      PA  1553207088        91   7.53  -80.03
# 1     Mataura          76      NZ  1553207217        83 -46.19  168.86
# 2   Esperance          20      TT  1553206807        58  10.24  -61.45
# 3  Butaritari          64      KI  1553207103       100   3.07  172.79
# 4    Vilyuysk           8      RU  1553207108        36  63.75  121.63
#
#    Max Temp  Wind Speed
# 0     77.29       13.18
# 1     61.81        4.12
# 2     86.00       10.29
# 3     81.88        8.14
# 4    -11.10        2.77

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
#create a latitude vs. temperature scatter plot

#x-axis
x_axis = city_weather_df["Lat"]

#y-axis
y_axis = city_weather_df["Max Temp"]

#create scatter plot
plt.scatter(x_axis, y_axis, marker="o", facecolors="blue", edgecolors="black",
            alpha=0.75)

#set x-limit
plt.xlim (-90,90)

#set y-limit
plt.ylim(0, 110)

#set a grid
plt.grid()

#label the plot
plt.title("City Latitude vs. Max Temperature")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")

#save figure
plt.savefig("Images/latVStemp.png")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
#create a latitude vs. humidity scatter plot

#x-axis
x_axis = city_weather_df["Lat"]

#y-axis
y_axis = city_weather_df["Humidity"]

#create scatter plot
plt.scatter(x_axis, y_axis, marker="o", facecolors="blue", edgecolors="black",
            alpha=0.75)

#set x-limit
plt.xlim (-90,90)

#set y-limit
plt.ylim(0, 110)

#set a grid
plt.grid()

#label the plot
plt.title("City Latitude vs. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

#save figure
plt.savefig("latVShumidity.png")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
#create a latitude vs. cloudiness scatter plot

#x-axis
x_axis = city_weather_df["Lat"]

#y-axis
y_axis = city_weather_df["Cloudiness"]

#create scatter plot
plt.scatter(x_axis, y_axis, marker="o", facecolors="blue", edgecolors="black",
            alpha=0.75)

#set x-limit
plt.xlim (-90,90)

#set y-limit
plt.ylim(0, 110)

#set a grid
plt.grid()

#label the plot
plt.title("City Latitude vs. Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

#save figure
plt.savefig("Images/latVScloudiness.png")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
#create a latitude vs. wind speed scatter plot

#x-axis
x_axis = city_weather_df["Lat"]

#y-axis
y_axis = city_weather_df["Wind Speed"]

#create scatter plot
plt.scatter(x_axis, y_axis, marker="o", facecolors="blue", edgecolors="black",
            alpha=0.75)

#set x-limit
plt.xlim (-90,90)

#set y-limit
plt.ylim(0, 55)

#set a grid
plt.grid()

#label the plot
plt.title("City Latitude vs. Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

#save figure
plt.savefig("Images/latVSwindspeed.png")
